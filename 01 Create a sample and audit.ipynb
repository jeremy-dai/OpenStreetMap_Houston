# %% [markdown]
# # This notebook is used to create a samller sample data and audit the data

# %%
# python 2 environment
# -*- coding: utf-8 -*-

import xml.etree.cElementTree as ET
from pprint import pprint as pp
import re
from collections import defaultdict

OSM_FILE = "houston_texas.osm" 
SAMPLE_FILE = "sample.osm"

# %%
# Create Sample Data
k = 80 # Parameter: take every k-th top level element

def get_element(osm_file, tags=('node', 'way', 'relation')):
    context = iter(ET.iterparse(osm_file, events=('start', 'end')))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


with open(SAMPLE_FILE, 'wb') as output:
    output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    output.write('<osm>\n  ')

    # Write every kth top level element
    for i, element in enumerate(get_element(OSM_FILE)):
        if i % k == 0:
            output.write(ET.tostring(element, encoding='utf-8'))

    output.write('</osm>')

# %%
#Check the attributes of nodes and ways
#print them out if they do not following the following format
nom=re.compile(r'^([a-z]|_)+:?([a-z]|_)+$')

def check_attributes(f):
    
    node_attributes = defaultdict(int)
    way_attributes = defaultdict(int)  
    for event, elem in ET.iterparse(f, events=("start",)):
        if elem.tag == "node":
            for tag in elem.iter("tag"): #find children tags
                m = nom.search(tag.attrib['k'].lower())
                if not m:      
                    if tag.get('k') not in node_attributes:
                        node_attributes[tag.get('k')]=1
                    else:   
                        
                        node_attributes[tag.get('k')]+=1
                
        if elem.tag == "way":
            for tag in elem.iter("tag"): #find children tags
                m = nom.search(tag.attrib['k'].lower())
                if not m:   
                    if tag.get('k') not in node_attributes:
                        way_attributes[tag.get('k')]=1
                    else:   
                        way_attributes[tag.get('k')]+=1

    return node_attributes,way_attributes
        
node_attributes,way_attributes = check_attributes(SAMPLE_FILE)

# %%
# print out the weird attributes of nodes
l=sorted( ((v,k) for k,v in node_attributes.iteritems()), reverse=True)
for v,k in l:
    print k,v
# Out:
# socket:type1 4
# voltage-high 2
# service:bicycle:rental 2
# service:bicycle:chain_tool 1
# name_1 1

# %%
# print out the weird attributes of ways
l=sorted( ((v,k) for k,v in way_attributes.iteritems()), reverse=True)
for v,k in l:
    print k,v
# Out:
# name_1 1508
# turn:lanes:forward 1
# turn:lanes:both_ways 1
# turn:lanes:backward 1
# tiger:zip_right_4 1
# tiger:zip_right_3 1
# tiger:zip_right_2 1
# tiger:zip_right_1 1
# tiger:zip_left_4 1
# tiger:zip_left_3 1
# tiger:zip_left_2 1
# tiger:zip_left_1 1
# tiger:name_type_4 1
# tiger:name_type_3 1
# tiger:name_type_2 1
# tiger:name_type_1 1
# tiger:name_direction_suffix_3 1
# tiger:name_direction_suffix_2 1
# tiger:name_direction_suffix_1 1
# tiger:name_direction_prefix_3 1
# tiger:name_direction_prefix_2 1
# tiger:name_direction_prefix_1 1
# tiger:name_base_4 1
# tiger:name_base_3 1
# tiger:name_base_2 1
# tiger:name_base_1 1
# roof:slope:direction 1
# plant:output:electricity 1
# parking:lane:right 1
# old_ref:pre_1939 1
# old_name_1 1
# note:toll:hov 1
# name_3 1
# name_2 1
# name:2 1
# name:1 1
# multi-story 1
# mtb:scale:uphill 1
# mtb:scale:imba 1
# leisure_1 1
# layer1 1
# is_in:iso_3166_2 1
# gnis:feature_id:old 1
# gnis:created:old 1
# generator:output:electricity 1
# addr:street_1 1
# access:lanes:both_ways 1

# %%
# check if there are nodes/ways calling for fixes.
def checkfixme(file):
    for _, element in ET.iterparse(file):
        if element.tag == "tag":
            if 'fixme' in element.get('k', None) or 'FIXME' in element.get('k', None) :
                print element.attrib
        
checkfixme(SAMPLE_FILE)
# Out:
# {'k': 'FIXME', 'v': 'This is an empty field hereabouts'}
# {'k': 'FIXME', 'v': 'This school does not exist at this location.  This location is a block of row houses.'}
# {'k': 'FIXME', 'v': 'Needs exact location; this is at least closer'}
# {'k': 'FIXME', 'v': 'confirm location'}
# {'k': 'FIXME', 'v': 'verify'}
# {'k': 'fixme', 'v': '33'}
# {'k': 'FIXME', 'v': 'Does Alief Clodine Rd change to Harwin Dr here?'}
# {'k': 'FIXME', 'v': 'continue'}
# {'k': 'fixme', 'v': 'Su-Th 11-22, Fr-Sa 11:00-23:00'}
# {'k': 'fixme', 'v': 'Double check this when construction is done'}
# {'k': 'FIXME', 'v': 'remove noexit when extending'}
# {'k': 'FIXME', 'v': 'continue path'}
# {'k': 'FIXME', 'v': 'Location approximated'}
# {'k': 'fixme', 'v': 'some structure there, guessing at dam from imagery'}
# {'k': 'FIXME', 'v': 'Location approximated'}
# {'k': 'fixme', 'v': 'confirm hours, may be open until 22:00'}
# {'k': 'FIXME', 'v': 'Add a gate or gap as appropriate'}
# {'k': 'FIXME', 'v': 'positions hidden by trees'}
# {'k': 'fixme', 'v': 'continue'}
# {'k': 'FIXME', 'v': 'check west end'}
# {'k': 'FIXME', 'v': 'verify name'}
# {'k': 'FIXME', 'v': 'confirm through routing'}
# {'k': 'FIXME', 'v': 'This does not match aerial'}
# {'k': 'FIXME', 'v': 'Glass Track Industrial Lead?'}
# {'k': 'FIXME', 'v': 'METRORail extension;rail line'}
# {'k': 'fixme', 'v': "the service roads here seem to go under pipes, but it's not clear if the do continue. Please verify. "}
# {'k': 'FIXME', 'v': "DOESN'T APPEAR TO BE A ROAD HERE IN BING"}
# {'k': 'FIXME', 'v': 'check lanes'}
# {'k': 'FIXME', 'v': 'verify bike lane for entire length'}
# {'k': 'FIXME:oneway', 'v': 'verify'}
# {'k': 'FIXME:oneway', 'v': 'verify'}
# {'k': 'FIXME', 'v': 'cycleway?'}
# {'k': 'FIXME', 'v': 'UP or PTRA?'}
# {'k': 'FIXME', 'v': 'bridge?'}
# {'k': 'FIXME', 'v': 'not dual carriageway'}
# {'k': 'FIXME', 'v': 'name?'}
# {'k': 'FIXME', 'v': 'check lanes'}
# {'k': 'FIXME', 'v': 'Is TIGER name wrong on one of these?'}
# {'k': 'FIXME', 'v': 'check lanes'}
# {'k': 'FIXME', 'v': 'Does this have a HOV lane or only a bus lane?'}
# {'k': 'FIXME', 'v': 'check lanes'}
# {'k': 'FIXME', 'v': 'Needs multipolygon skills to add the two island hubcaps'}
# {'k': 'FIXME', 'v': 'check lanes'}
# {'k': 'FIXME', 'v': 'check lanes'}
# {'k': 'FIXME', 'v': 'Road geometry may have changed see http://www.katyfreeway.net/images/schematics_pdf/reeval_schematics.pdf for details'}
# {'k': 'FIXME', 'v': 'check lanes'}
# {'k': 'FIXME', 'v': 'check lanes'}
# {'k': 'FIXME', 'v': 'not dual carriageway'}
# {'k': 'FIXME', 'v': 'continue west'}
# {'k': 'FIXME', 'v': 'continue west'}
# {'k': 'FIXME', 'v': 'check lanes'}
# {'k': 'FIXME', 'v': 'need name, not in TIGER 2012'}
# {'k': 'FIXME', 'v': 'name? not in TIGER 2012'}
# {'k': 'FIXME', 'v': 'Name? not in TIGER 2012'}
# {'k': 'FIXME', 'v': 'closed?'}
# {'k': 'FIXME', 'v': 'need name'}
# {'k': 'FIXME', 'v': 'check lanes'}
# {'k': 'FIXME', 'v': 'need names and more roads'}
# {'k': 'FIXME', 'v': 'need name'}
# {'k': 'FIXME', 'v': 'need names'}
# {'k': 'FIXME', 'v': 'need name'}
# {'k': 'FIXME', 'v': 'need names and more roads'}
# {'k': 'FIXME', 'v': 'need names'}
# {'k': 'FIXME', 'v': 'Need names and more roads'}
# {'k': 'FIXME', 'v': 'need names'}
# {'k': 'FIXME', 'v': 'Need names'}
# {'k': 'FIXME', 'v': 'names'}
# {'k': 'FIXME', 'v': 'need name'}
# {'k': 'FIXME', 'v': 'need name, not in TIGER 2012'}
# {'k': 'FIXME', 'v': 'verify bike lane for entire length'}
# {'k': 'FIXME', 'v': 'Really, this is a manicured collection of trees, not a forest'}
# {'k': 'FIXME', 'v': 'fix alignment w.r.t. roadways'}
# {'k': 'FIXME', 'v': 'verify bike lane for entire length'}
# {'k': 'FIXME', 'v': 'need names, not in TIGER 2012'}
# {'k': 'FIXME', 'v': 'name'}
# {'k': 'FIXME', 'v': 'need names? Not in TIGER 2012'}
# {'k': 'FIXME', 'v': 'Does this have a route number now?'}
# {'k': 'FIXME', 'v': 'verify name change locacation'}
# {'k': 'FIXME', 'v': 'need name'}
# {'k': 'FIXME', 'v': 'Need names in new subdivision'}
# {'k': 'FIXME', 'v': 'dual carriageway'}
# {'k': 'FIXME', 'v': 'verify name'}
# {'k': 'FIXME', 'v': "Check alignment. This is just from memory, not from a GPS track. It's close though."}
# {'k': 'FIXME', 'v': 'location approximated'}
# {'k': 'FIXME', 'v': 'name?'}
# {'k': 'fixme', 'v': 'verify existence, no longer on imagery'}
# {'k': 'FIXME', 'v': 'divided'}
# {'k': 'FIXME', 'v': 'check lanes'}
# {'k': 'FIXME', 'v': 'Location approximated from Bing'}
# {'k': 'fixme', 'v': 'source = guess'}
# {'k': 'FIXME', 'v': 'dual carriageway'}
# {'k': 'FIXME', 'v': 'continues underground'}
# {'k': 'FIXME', 'v': 'alignment and dualize'}
# {'k': 'FIXME', 'v': 'alignment'}
# {'k': 'FIXME', 'v': 'divided'}
# {'k': 'FIXME', 'v': 'divided'}
# {'k': 'FIXME', 'v': 'Area approximated from Bing'}
# {'k': 'fixme', 'v': 'verify names'}
# {'k': 'FIXME', 'v': 'need more roads'}
# {'k': 'FIXME', 'v': 'check lanes'}
# {'k': 'FIXME', 'v': 'Need names and more roads'}
# {'k': 'FIXME', 'v': 'verify bike lane for entire length'}
# {'k': 'fixme', 'v': 'Lane information requires more detail'}
# {'k': 'FIXME', 'v': 'US 290 Business?'}
# {'k': 'FIXME', 'v': 'check lanes'}
# {'k': 'FIXME', 'v': 'verify bike lane for entire length'}
# {'k': 'FIXME', 'v': 'alignment'}
# {'k': 'FIXME', 'v': 'alignment'}
# {'k': 'FIXME', 'v': 'alignment'}
# {'k': 'FIXME', 'v': 'alignment'}
# {'k': 'FIXME', 'v': 'alignment'}
# {'k': 'fixme', 'v': 'dual carriageway'}
# {'k': 'FIXME', 'v': 'Need names and roads'}
# {'k': 'FIXME', 'v': 'Does this have a route number now?'}
# {'k': 'FIXME', 'v': 'Does this have a route number now?'}
# {'k': 'FIXME', 'v': 'dual carriageway'}
# {'k': 'FIXME', 'v': 'name?'}
# {'k': 'FIXME', 'v': "needs updated high-quality imagery (NAIP isn't cutting it)"}
# {'k': 'FIXME', 'v': 'Check names'}
# {'k': 'FIXME', 'v': 'METRORail extension;rail line'}
# {'k': 'fixme', 'v': 'verify correct tagging'}
# {'k': 'FIXME', 'v': 'how does one tag a teepee which may sometimes be present?'}
# {'k': 'FIXME', 'v': 'Road geometry may have changed see http://www.katyfreeway.net/images/schematics_pdf/reeval_schematics.pdf for details'}
# {'k': 'FIXME', 'v': 'Exactly where is the east end?'}
# {'k': 'FIXME', 'v': 'verify east end'}

# %%
# checck if the nodes are within the Greater Houston Area
def checklocation():
    lat=set()
    lon=set()
    for _, element in ET.iterparse('sample.osm'):
        if element.tag == "node":
            lat.add(element.get('lat', None) )
            lon.add(element.get('lon', None) )
    return lat,lon
lat,lon=checklocation()

print min(lat),min(lon)
print max(lat),max(lon)
# Out:
# 28.8560051 -94.378062
# 30.2609976 -96.063993

# %%
# check zipcode, left and right
def checkzipcode():
    zip=set()
    for _, element in ET.iterparse('sample.osm'):
        if element.tag == "tag":
            if element.get('k', None)=='tiger:zip_left':
                n=element.get('v', None)
                zip.add(n)           
            if element.get('k', None)=='tiger:zip_right':
                n=element.get('v', None)
                zip.add(n) 
            if element.get('k', None)=='addr:postcode':
                n=element.get('v', None)
                zip.add(n)                 
    problemzip=[]
    for z in zip:
        try:
            z=int(z)
            # if the zipcode is not Houston area, add it into the list
            if z < 77000 or z > 77999:
                problemzip.append(z)
        except:
            problemzip.append(z)
                
    return problemzip

zip=checkzipcode()
pp(zip)
# Out:
# ['77002; 77004',
#  '77024; 77024; 77036',
#  '77338:77346',
#  '77045;77489',
#  '77489; 77085',
#  '77099:77478',
#  '77077:77084',
#  '77004:77023',
#  '77031:77074',
#  '77037;77076',
#  '77088:77091',
#  '77031:77035',
#  '77022;77076;77009',
#  '77024; 77063',
#  '77009:77022',
#  '77571; 77587',
#  '77026:77050',
#  '77016:77026',
#  '77091;77076',
#  '77373:77388',
#  '77429; 77095',
#  '77002;77004']

# %%
# check the keys of Tiger GPS data
def checktiger(file):
    tigers=defaultdict(int)
    for _, element in ET.iterparse(file):
        if element.tag == "tag":
            if 'tiger' in element.get('k'):
                tigers[element.get('k')]+=1
    return tigers

tigers=checktiger(SAMPLE_FILE)

l=sorted( ((v,k) for k,v in tigers.iteritems()), reverse=True)
for v,k in l:
    print k,v
# Out:
# tiger:county 16441
# tiger:cfcc 16335
# tiger:reviewed 13565
# tiger:name_base 10702
# tiger:name_type 9534
# tiger:source 7267
# tiger:tlid 7211
# tiger:zip_left 7185
# tiger:zip_right 6733
# tiger:separated 6571
# tiger:upload_uuid 3321
# tiger:name_base_1 1526
# tiger:name_direction_prefix 852
# tiger:name_type_1 732
# tiger:zip_left_1 324
# tiger:name_base_2 212
# tiger:name_direction_prefix_1 128
# tiger:name_direction_suffix 126
# tiger:zip_right_1 125
# tiger:name_type_2 125
# tiger:name_direction_suffix_1 88
# tiger:state_id 75
# tiger:zip_left_2 67
# tiger:mtfcc 59
# tiger:name_base_3 30
# tiger:rttyp 28
# tiger:zip_right_2 27
# tiger:zip_left_3 21
# tiger:name_direction_suffix_2 20
# tiger:STATEFP 16
# tiger:PLCIDFP 16
# tiger:PLACENS 16
# tiger:PLACEFP 16
# tiger:PCINECTA 16
# tiger:PCICBSA 16
# tiger:NAMELSAD 16
# tiger:NAME 16
# tiger:MTFCC 16
# tiger:LSAD 16
# tiger:FUNCSTAT 16
# tiger:CPI 16
# tiger:CLASSFP 16
# tiger:zip_right_3 13
# tiger:name_direction_prefix_2 12
# tiger:name_type_3 10
# tiger:zip_left_4 7
# tiger:zip 3
# tiger:name_base_4 3
# tiger:zip_right_4 2
# tiger:name_type_4 2
# tiger:name_direction_suffix_3 1
# tiger:name_direction_prefix_3 1
# tiger:base_name 1

# %%
# check if there will be tags of add:street and tiger:name_base under the same way element
def checkaddress(osmfile):
    osm_file = open(osmfile, "r")
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            n=0
            for tag in elem.iter("tag"): #find children tags
                if tag.get('k') =='addr:street' :
                    n+=1
                if tag.get('k') == 'tiger:name_base':
                    n+=1
            if n==2:
                print elem
        
    osm_file.close()

checkaddress(SAMPLE_FILE)

# %%
#Audit Street Names

street_type_re = re.compile(r'\S+\.?$', re.IGNORECASE)
street_type_prefix = re.compile(r'^([NSWE])\s', re.IGNORECASE)
street_type_suffix = re.compile(r'\s([NSWE])$', re.IGNORECASE)
street_type_number = re.compile(r'\s#?\d+[a-zA-Z]?$', re.IGNORECASE)


expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons","Freeway","Highway",'Circle','Speedway','Way','Loop']

mapping = { "Cir": "Circle","Ct": "Court",'Dr':'Drive','Ln':'Lane','Fwy':'Freeway',
           'Pkwy':"Parkway",'Pky':"Parkway","Ave": "Avenue", 'Blvd':'Boulevard','Hwy':'Highway',
           'Rd':'Road','St':'Street','Pl':'Place','Trl':"Trail",'Blvd.':'Boulevard',
           'Byp':'Bypass'}

def update_name(name, mapping):
    subwords=name.split()
    lastword=subwords[-1]
    if lastword in mapping:
        subwords[-1]=mapping[lastword]
        name=' '.join(subwords)
    return name

def audit_street_type(street_types, street_name):
    #if there is a suffix, leave it out
    if street_type_suffix.search(street_name): 
        street_name=(' ').join(street_name.split()[:-1])
    #after moving the suffix, if there is a number, leave it out
    if street_type_number.search(street_name): 
        street_name=(' ').join(street_name.split()[:-1])
    #print out the street name if its updated last word is not in the mapping
    if street_type_re.search(street_name):
        street_name = update_name(street_name,mapping)
        street_type = street_type_re.search(street_name).group()
        if street_type not in expected:
            street_types[street_type].add(street_name)


def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)  #defaultdict
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            iftiger=False
            name_base,name_type,name_direction_prefix,name_direction_suffix=None,None,None,None
            for tag in elem.iter("tag"): #find children tags
                if tag.get('k') == 'addr:street':
                    audit_street_type(street_types, tag.attrib['v'])
                #complie the Tiger GPS name
                if tag.get('k') == 'tiger:name_base':
                    iftiger=True
                    name_base=re.split('[:;]',tag.get('v'))[0] 
                if tag.get('k') == 'tiger:name_type':
                    name_type=re.split('[:;]',tag.get('v'))[0] 
                if tag.get('k') == 'tiger:name_direction_prefix':
                    name_direction_prefix=re.split('[:;]',tag.get('v'))[0] 
                if tag.get('k') == 'tiger:name_direction_suffix':
                    name_direction_suffix=re.split('[:;]',tag.get('v'))[0] 
            if iftiger: 
                streetlist=[name_direction_prefix,name_base,name_type,name_direction_suffix]
                street=' '.join(filter(None,streetlist)) 
                audit_street_type(street_types,street)
    osm_file.close()
    return street_types



if __name__ == '__main__':
    st_types = audit(SAMPLE_FILE)
    pp(dict(st_types))
# Out:
# {'#N': set(['Kingwood Drive #N']),
#  '(Alt)': set(['United States Highway 90 (Alt)']),
#  '(Bus)': set(['State Highway 288B (Bus)', 'United States Highway 59 (Bus)']),
#  '(Ssr)': set(['South Service Rd (Ssr)']),
#  '1/2': set(['Avenue G 1/2',
#              'Avenue M 1/2',
#              'Avenue N 1/2',
#              'Avenue O 1/2',
#              'Avenue P 1/2',
#              'Avenue Q 1/2',
#              'Avenue T 1/2']),
#  '13384': set(['13384']),
#  '191C': set(['191C']),
#  '2004': set(['2004']),
#  '206': set(['206']),
#  '228': set(['228']),
#  '24A': set(['24A']),
#  '300': set(['300']),
#  '348': set(['348']),
#  '456': set(['456']),
#  '545': set(['545']),
#  '566': set(['566']),
#  '610A': set(['610A']),
#  '868E': set(['868E']),
#  'A': set(['Avenue A', 'N Avenue A']),
#  'Acres': set(['Acres']),
#  'Afloat': set(['Afloat']),
#  'Agee': set(['Agee']),
#  'Airline': set(['Airline', 'Stuebner Airline']),
#  'Allyne': set(['Allyne']),
#  'Aly': set(['Hogans Aly']),
#  'Arcadia': set(['Arcadia']),
#  'Ashe': set(['Ashe']),
#  'Atascadero': set(['Atascadero']),
#  'Audley': set(['Audley']),
#  'Avens': set(['Avens']),
#  'B': set(['Avenue B', 'Dow Operations Plant B', 'Joe B', 'Road B']),
#  'Balbo': set(['Balbo']),
#  'Bar': set(['Three Bar']),
#  'Base': set(['Base']),
#  'Basil': set(['Basil']),
#  'Bastrop': set(['Bastrop']),
#  'Bay': set(['Half Moon Bay']),
#  'Bayer': set(['Bayer']),
#  'Bayglen': set(['Bayglen']),
#  'Beltway': set(['Beltway', 'State Beltway']),
#  'Bend': set(['Bluebird Bend',
#               'Branch Bend',
#               'Creek Bend',
#               'E Palmer Bend',
#               'Hunters Bend',
#               'Lakegrove Bend',
#               'Manor Bend',
#               'River-Oak Bend',
#               'S Willoki Bend',
#               'Shadow Bend',
#               'Sunrise Bend']),
#  'Bernadetta': set(['Santa Bernadetta']),
#  'Bight': set(['S Flamingo Bight']),
#  'Blaffer': set(['Blaffer']),
#  'Bligh': set(['Captain Bligh']),
#  'Blossom': set(['Magnolia Blossom']),
#  'Bonney': set(['Bonney']),
#  'Boom': set(['Boom']),
#  'Bostick': set(['Bostick']),
#  'Br': set(['S Br', 'South Br']),
#  'Bracknell': set(['Bracknell']),
#  'Briar': set(['South Briar']),
#  'Brisas': set(['Las Brisas']),
#  'Broadbury': set(['West Broadbury']),
#  'Broadway': set(['Broadway', 'N Broadway']),
#  'Brown': set(['Brown']),
#  'Buccaneer': set(['Buccaneer']),
#  'Burdine': set(['Burdine']),
#  'Burlington': set(['Burlington']),
#  'Burnett': set(['Burnett']),
#  'Business': set(['TX-288 Business']),
#  'Butlercrest': set(['Butlercrest']),
#  'Buvinghausen': set(['Buvinghausen']),
#  'Bypass': set(['F-M Rd 1960 Bypass']),
#  'Byram': set(['Byram']),
#  'C': set(['Avenue C', 'C', 'S Avenue C']),
#  'Cactus': set(['Cactus']),
#  'Call': set(['Mc Call']),
#  'Canary': set(['Canary']),
#  'Canyon': set(['Fox Canyon']),
#  'Carmel': set(['Carmel']),
#  'Carmita': set(['Carmita']),
#  'Carter': set(['Carter']),
#  'Carver': set(['Carver']),
#  'Casamare': set(['Casamare']),
#  'Casey': set(['Casey']),
#  'Cecilia': set(['St Cecilia']),
#  'Central': set(['Central']),
#  'Chapman': set(['Chapman']),
#  'Charles': set(['Charles']),
#  'Charpiot': set(['W Charpiot']),
#  'Chase': set(['Chase', 'Marywood Chase']),
#  'Cinderella': set(['Cinderella']),
#  'Clarcel': set(['Clarcel']),
#  'Clark': set(['Clark']),
#  'Cmn': set(['Chervil Cmn']),
#  'Company': set(['Amoco Chemical Company', 'Phillips 66 Company']),
#  'Concho': set(['Concho']),
#  'Cortis': set(['Cortis']),
#  'Cote': set(['Belle Cote']),
#  'Cougar': set(['Cougar']),
#  'Country': set(['Hill Country']),
#  'Cr': set(['Texaco Cr']),
#  'Cr161': set(['Cr161']),
#  'Creek': set(['Cherry Creek',
#                'Cougar Creek',
#                'Creek',
#                'Misty Creek',
#                'Pine Creek',
#                'Ripple Creek',
#                'Roaring Creek']),
#  'Creekside': set(['Creekside']),
#  'Creekview': set(['Creekview']),
#  'Cres': set(['Hyde Park Cres']),
#  'Crest': set(['Royal Crest', 'York Crest']),
#  'Cross': set(['Kings Cross']),
#  'Crosshaven': set(['Crosshaven']),
#  'Crsg': set(['Crsg']),
#  'Cut': set(['Queens Cut']),
#  'Cv': set(['Antwerp Cv',
#             'Autumn Mist Cv',
#             'Baker Cv',
#             'Birch Cv',
#             'Chateau Cv',
#             'Explorer Cv',
#             'Huntington Cv',
#             'Jamaica Cv',
#             'Jean Lafitte Cv',
#             'Kingston Cv',
#             'Mariner Cv',
#             'Mossy Ridge Cv',
#             'Portz Cv',
#             'Sandy Cv',
#             'Tracewood Cv']),
#  'Cypress': set(['Barker Cypress', 'Cypress']),
#  'Cypresswood': set(['Cypresswood']),
#  'D': set(['Avenue D']),
#  'Daffodil': set(['Daffodil']),
#  'Dale': set(['Crown Dale']),
#  'Danville': set(['Danville']),
#  'Dawn': set(['New Dawn']),
#  'Dean': set(['Dean']),
#  'Defee': set(['Defee']),
#  "Despain's": set(["Despain's"]),
#  'Diesel': set(['Diesel']),
#  'Diplomat': set(['Diplomat']),
#  'Ditch': set(['Salt Water Ditch']),
#  'Dodge': set(['Dodge']),
#  'Dogwood': set(['Dogwood']),
#  'Donald': set(['Mc Donald']),
#  'Doreen': set(['Doreen']),
#  'Driscoll': set(['Driscoll']),
#  'Duke': set(['Duke']),
#  'Dunn': set(['Dunn']),
#  'E': set(['Farm to Market 1960 Bypass E']),
#  'Eaglecrest': set(['Eaglecrest']),
#  'Easley': set(['Easley']),
#  'East': set(['Conquistador East', 'FM 1960 East']),
#  'Eastchase': set(['Eastchase']),
#  'Echo': set(['Glen Echo']),
#  'Edge': set(['Champions Edge']),
#  'Edgewind': set(['Edgewind']),
#  'Edwards': set(['Edwards']),
#  'Elm': set(['Elm']),
#  'Entrance': set(['Port Entrance']),
#  'Escuela': set(['Escuela']),
#  'Estates': set(['Holly Court Estates']),
#  'Everett': set(['Everett']),
#  'Ewing': set(['Ewing']),
#  'Expy': set(['Emmett F Lowry Expy']),
#  'F': set(['Avenue F', 'F', 'S Avenue F']),
#  'F-M': set(['F-M']),
#  'FM': set(['FM']),
#  'Fairhill': set(['Fairhill']),
#  'Fairway': set(['Barrington Fairway', 'Grand Fairway']),
#  'Fallbrook': set(['Fallbrook']),
#  'Falls': set(['Meadow Falls']),
#  'Fanestiel': set(['Fanestiel']),
#  'Farms': set(['Turkey Creek Farms']),
#  'Fieldstone': set(['Fieldstone']),
#  'Fitzgerald': set(['Fitzgerald']),
#  'Flyway': set(['Flyway']),
#  'Forest': set(['Pine Forest', 'Rolling Forest']),
#  'Four': set(['Shepherd Pr Four']),
#  'Fox': set(['Red Fox']),
#  'Foxbend': set(['Foxbend']),
#  'Freehill': set(['Freehill']),
#  'Front': set(['Lake Front']),
#  'G': set(['Avenue G', 'N Avenue G']),
#  'Gardenia': set(['Gardenia']),
#  'Garrison': set(['Garrison']),
#  'Gate': set(['Brandon Gate']),
#  'Gayhart': set(['Gayhart']),
#  'Gayle': set(['Gayle']),
#  'Gessner': set(['Gessner']),
#  'Giamfortone': set(['Giamfortone']),
#  'Glen': set(['Meadow Glen', 'Willow Glen']),
#  'Goldfarb': set(['Goldfarb']),
#  'Granada': set(['Granada']),
#  'Grand': set(['Grand']),
#  'Grange': set(['La Grange']),
#  'Grape': set(['Grape']),
#  'Green': set(['S Country Club Green', 'W Cottage Green']),
#  'Greensides': set(['Greensides']),
#  'Greentree': set(['Greentree']),
#  'Greenwood': set(['Greenwood']),
#  'Grove': set(['Big Oaks Grove', 'Concord Grove', 'Wortham Grove']),
#  'Gulf': set(['Gulf']),
#  'H': set(['Avenue H']),
#  'Hamilton': set(['Hamilton']),
#  'Hancock': set(['Hancock']),
#  'Harbor': set(['Bay Harbor', 'Bridge Harbor']),
#  'Hardin': set(['Hardin']),
#  'Harris': set(['Harris']),
#  'Hawthorne': set(['Hawthorne']),
#  'Heathfield': set(['Heathfield']),
#  'Henderso': set(['Galveston Houston and Henderso']),
#  'Hicksfield': set(['Hicksfield']),
#  'Hill': set(['Blanco Hill', 'Judson Hill', 'Senina Hill', 'Willis Hill']),
#  'Hillcroft': set(['Hillcroft']),
#  'Hillhouse': set(['Hillhouse']),
#  'Hollock': set(['Hollock']),
#  'Hollow': set(['Echo Hollow',
#                 'Pine Hollow',
#                 'Shady Hollow',
#                 'Timber Hollow']),
#  'Holly': set(['Holly']),
#  'Howell': set(['Addicks Howell']),
#  'I': set(['Avenue I', 'I']),
#  'I-10': set(['I-10']),
#  'I-45': set(['I-45']),
#  'I-610': set(['I-610']),
#  'Indian': set(['Indian']),
#  'Ironwood': set(['Ironwood']),
#  'Island': set(['Pelican Island']),
#  'Isle': set(['Morgan Isle']),
#  'J': set(['Avenue J']),
#  'Jander': set(['Jander']),
#  'Jerry': set(['Jerry']),
#  'Jester': set(['T C Jester']),
#  'K': set(['Avenue K']),
#  'Kathy': set(['Kathy']),
#  'Kelly': set(['Kelly']),
#  'Kelso': set(['Kelso']),
#  'Kentucky': set(['Kentucky']),
#  'Key': set(['Brewster Key']),
#  'Kingwood': set(['Kingwood']),
#  'Kinney': set(['Kinney']),
#  'Kirkwood': set(['Kirkwood']),
#  'L': set(['Avenue L']),
#  'Ladona': set(['Ladona']),
#  'Lagoon': set(['Blue Lagoon']),
#  'Lake': set(['Azure Lake',
#               'Fawn Lake',
#               'Inverness Lake',
#               'Long Lake',
#               'Old Bridge Lake',
#               'Plum Lake']),
#  'Landing': set(['Creekwood Landing',
#                  'Harpers Landing',
#                  'Jonathons Landing',
#                  'Spring Landing']),
#  'Landmark': set(['Landmark']),
#  'Larkspur': set(['Larkspur']),
#  'Leaf': set(['Bristle Leaf']),
#  'Linden': set(['Linden']),
#  'Line': set(['Transmission Line']),
#  'Lloyd': set(['Lloyd']),
#  'Lodgebrook': set(['Lodgebrook']),
#  'Longbow': set(['Longbow']),
#  'Louisiana': set(['Louisiana']),
#  'Luella': set(['Luella']),
#  'M': set(['Avenue M']),
#  'Magnolia': set(['Magnolia']),
#  'Main': set(['Main', 'S Main']),
#  'Mark': set(['Mark']),
#  'Mayflower': set(['Mayflower']),
#  'McArthur': set(['McArthur']),
#  'McKinnon': set(['McKinnon']),
#  'Meadow': set(['Plantation Meadow', 'Tree Meadow']),
#  'Melton': set(['Melton']),
#  'Meyer': set(['Meyer']),
#  'Milby': set(['Milby']),
#  'Miley': set(['Miley']),
#  'Mist': set(['Hidden Mist']),
#  'Mo': set(['Private Road 164 Mo']),
#  'Monaville': set(['Monaville']),
#  'Montgomery': set(['Montgomery']),
#  'Moore': set(['Moore']),
#  'Morenci': set(['Morenci']),
#  'Morning': set(['Misty Morning']),
#  'NE': set(['Oilfield Rd NE']),
#  'Nallie': set(['Nallie']),
#  'Natchez': set(['Natchez']),
#  'Nazro': set(['Nazro']),
#  'Nicholas': set(['Mc Nicholas']),
#  'No': set(['Lockridge Rd No', 'Miller Rd No', 'Rollover No']),
#  'Noble': set(['Noble']),
#  'North': set(['25th Avenue North', 'Highway 6 North']),
#  'Norwich': set(['Norwich']),
#  'Number': set(['Miller Rd Number']),
#  'O': set(['Avenue O']),
#  'Oak': set(['Country Oak',
#              'Green Oak',
#              'Lazy Oak',
#              'Live Oak',
#              'Mighty Oak',
#              'S Oak',
#              'W Oak']),
#  'Oaks': set(['Autumn Oaks',
#               'English Oaks',
#               'Fair Oaks',
#               'Grand Oaks',
#               'Seven Oaks',
#               'Tall Oaks',
#               'Willow Oaks']),
#  'Orem': set(['W Orem']),
#  'Osborn': set(['Vincent Osborn']),
#  'Overland': set(['Overland']),
#  'P': set(['E Avenue P']),
#  'Palace': set(['Palace']),
#  'Palmleaf': set(['Palmleaf']),
#  'Palmridge': set(['Palmridge']),
#  'Park': set(['Anchor Park',
#               'Beling National Park',
#               'Cambry Park',
#               'Charlton Park',
#               'Crestwood Park',
#               'Gillman Park',
#               'Glenmont Park',
#               'James H Robbins Park',
#               'Kensington Park',
#               'Lake Park',
#               'Live Oak Park',
#               'Marymont Park',
#               'Melody Park',
#               'Monitor Park',
#               'North Carolina Park',
#               'Oakwood Park',
#               'Park',
#               'Shenandoah Park',
#               'Tara Park',
#               'Wellington Park',
#               'Wren Park']),
#  'Parkline': set(['Parkline']),
#  'Pass': set(['Baton Pass', 'Cameray Pass']),
#  'Patch': set(['Patch']),
#  'Path': set(['Clover Path', 'Flagstone Path', 'Pebble Path']),
#  'Pawnee': set(['Pawnee']),
#  'Peace': set(['Peace']),
#  'Peach': set(['Peach']),
#  'Perkins': set(['Perkins']),
#  'Phail': set(['Mc Phail']),
#  'Pine': set(['Lazy Pine', 'Pine', 'W Pine']),
#  'Pines': set(['Sand Pines']),
#  'Pipeline': set(['Pipeline']),
#  'Pk': set(['Oakridge Trailer Pk']),
#  'Plant': set(['Dow Chemical Plant']),
#  'Plaza': set(['One Baylor Plaza']),
#  'Point': set(['Ashlar Point',
#                'E Palmer Point',
#                'Gulf Prairie Point',
#                'Laguna Point',
#                'Lake Point',
#                'Needle Point',
#                'Peltier Point',
#                'Rika Point',
#                'Spring Branch Point',
#                'Wellington Point']),
#  'Pointe': set(['Walnut Pointe']),
#  'Pontiff': set(['Pontiff']),
#  'Poplar': set(['N Poplar']),
#  'Porter': set(['Porter']),
#  'Powerpoint': set(['Powerpoint']),
#  'Pr': set(['Pr']),
#  'Prestwick': set(['Prestwick']),
#  'Providence': set(['Providence']),
#  'Pruitt': set(['Pruitt']),
#  'Pumpkin': set(['Pumpkin']),
#  'Q': set(['Avenue Q']),
#  'R': set(['Avenue R', 'Burlington Northern Santa Fe R', 'C R', 'E Avenue R']),
#  'Railroad': set(['Burlington Northern Railroad',
#                   'Missouri Pacific Railroad',
#                   'Port Terminal Railroad',
#                   'Railroad',
#                   'Southern Pacific Railroad',
#                   'Texas Central Railroad',
#                   'Union Pacific Railroad']),
#  'Railway': set(['At and Sf Railway', 'Kansas City Southern Railway']),
#  'Railwood': set(['Railwood']),
#  'Ranch': set(['Bridgestone Ranch', 'Moon Lake Ranch', 'Riverbend Ranch']),
#  'Real': set(['El Camino Real']),
#  'Reed': set(['Golden Reed']),
#  'Refuge': set(['San Bernard Wildlife Refuge']),
#  'Rest': set(['Travelers Rest']),
#  'Rhodes': set(['Rhodes']),
#  'Ridge': set(['Country Ridge', 'Creek Ridge', 'Rocksprings Ridge']),
#  'River': set(['Down River', 'Saber River']),
#  'Rock': set(['Chimney Rock', 'Craggy Rock']),
#  'Roeller': set(['N Roeller']),
#  'Rolish': set(['Rolish']),
#  'Rosewood': set(['Rosewood']),
#  'Route': set(['Aldine Mail Route']),
#  'Row': set(['Park Row']),
#  'Run': set(['Carriage Run',
#              'Cedar Run',
#              'Deer Run',
#              'Raccoon Run',
#              'Seascape Run']),
#  'Runnels': set(['Runnels']),
#  'Ry': set(['Houston Belt and Terminal Ry']),
#  'S': set(['West Loop S']),
#  'Sakowitz': set(['Sakowitz']),
#  'Sandman': set(['Sandman']),
#  'Sandstone': set(['Sandstone']),
#  'Scarlet': set(['Will Scarlet']),
#  'Schilling': set(['Schilling']),
#  'Serrato': set(['Serrato']),
#  'Shaw': set(['Shaw']),
#  'Shore': set(['Shore']),
#  'Shores': set(['Angel Shores']),
#  'Simmons': set(['Simmons']),
#  'Sneider': set(['Sneider']),
#  'Sol': set(['Isla del Sol']),
#  'Solo': set(['Solo']),
#  'South': set(['Sagecircle South',
#                'West Grand Parkway South',
#                'West Sam Houston Pkwy South']),
#  'Southampton': set(['Southampton']),
#  'Spring': set(['Big Spring',
#                 'Magnolia Spring',
#                 'Mason Spring',
#                 'Union Spring']),
#  'Spur': set(['Del Bello Spur', 'State Spur']),
#  'Sq': set(['Canyon Creek Sq', 'Colony Sq', 'Provence Sq', 'Shasta Sq']),
#  'St.': set(['East 13th St.']),
#  'Staffordshire': set(['Staffordshire']),
#  'Star': set(['N Star']),
#  'Ste': set(['Lake Woodlands Dr, Ste']),
#  'Sterling': set(['N Ross Sterling']),
#  'Stone': set(['North Gate Stone']),
#  'Strawberry': set(['Strawberry']),
#  'Svrd': set(['N Loop Fwy Svrd']),
#  'Swashbuckle': set(['Swashbuckle']),
#  'Sycamore': set(['Sycamore']),
#  'T': set(['Avenue T']),
#  'TX': set(['TX']),
#  'TX-6': set(['TX-6']),
#  'Tala': set(['Tala']),
#  'Tamworth': set(['Tamworth']),
#  'Tangerine': set(['Tangerine']),
#  'Tangley': set(['Tangley']),
#  'Tarver': set(['Tarver']),
#  'Tate': set(['Tate']),
#  'Taylor': set(['Taylor', 'W Taylor']),
#  'Ter': set(['2nd Ter',
#              'Cate Ter',
#              'Mark Ter',
#              'Phillips 66 Co Clemens Ter',
#              'S Falls Ter',
#              'Torchlite Ter',
#              'Wynell Ter']),
#  'Texas': set(['BIRNHAM WOODS DRIVE SPRING, Texas']),
#  'Thicact': set(['Thicact']),
#  'Timbers': set(['High Timbers']),
#  'Tr': set(['Redwood Bridge Tr']),
#  'Tralee': set(['Tralee']),
#  'Travis': set(['Travis']),
#  'Trce': set(['Deer Trce', 'Indian Autumn Trce', 'Steep Bank Trce']),
#  'Triple': set(['Triple']),
#  'Tunnel': set(['West Dallas Tunnel']),
#  'Turn': set(['Morgans Turn']),
#  'U': set(['Avenue U']),
#  'US': set(['US']),
#  'V': set(['Avenue V']),
#  'Valinda': set(['Valinda']),
#  'Valverde': set(['Valverde']),
#  'Verkin': set(['Verkin']),
#  'Veronica': set(['Veronica']),
#  'View': set(["Beacon's View", 'Cove View', 'East View', 'Palm View']),
#  'Village': set(['Parklake Village']),
#  'Ville': set(['Rue de Ville']),
#  'Virginia': set(['Virginia']),
#  'Walk': set(['Garden Walk']),
#  'Walnut': set(['S Walnut']),
#  'Wanda': set(['Wanda']),
#  'Ward': set(['Ward']),
#  'Warington': set(['Warington']),
#  'Waterlake': set(['West Waterlake']),
#  'Waycrest': set(['Waycrest']),
#  'Wealder': set(['W Wealder']),
#  'Welford': set(['Welford']),
#  'West': set(['Interdrive West',
#               'North Loop West',
#               'South Sam Houston Parkway West']),
#  'Westover': set(['Westover']),
#  'Westray': set(['Westray']),
#  'Westview': set(['Westview']),
#  'Wind': set(['Cypress Wind']),
#  'Windsor': set(['Windsor']),
#  'Woodham': set(['Woodham']),
#  'Woods': set(['Alden Woods']),
#  'Wye': set(['Texas City Wye', 'Wye']),
#  'Xing': set(['Braes Xing',
#               'Emory Xing',
#               'Oak Xing',
#               'Parkriver Xing',
#               'River Xing']),
#  'Yates': set(['Yates']),
#  'York': set(['Court of York'])}
